# %% [markdown]
# # Programación 201

# %% [markdown]
# ### Ejercicio 1
#
# Carga los datos desde el archivo `netflixtitles.csv` , que puedes encontrar en la carpeta `data`, en un *dataframe*. Este conjunto de datos recoje información sobre películas y séries de TV de Netflix (https://www.kaggle.com/shivamb/netflix-shows) hasta el 2019.
#
# Muestra el número de filas del *dataframe* y los nombres de las columnas.
#
# *Consideraciones:*
#
# *  Muestra únicamente la información pedida en el enunciado.

# %%
# Respuesta
# Importamos las librerías

import pandas as pd
import numpy as np

# %%
# Cargamos los datos del archivo csv en un dataframe

df_netflix = pd.read_csv('netflix_titles.csv')

# %%
# Observamos el dataframe

df_netflix
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# 6229                       NaN
# 6230                       NaN
# 6231                       NaN
# 6232                       NaN
# 6233                       NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3     Will Friedle, Darren Criss, Constance Zimmer, ...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...                                                 ...
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6231                                                NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                                        country         date_added  \
# 0     United States, India, South Korea, China  September 9, 2019
# 1                               United Kingdom  September 9, 2016
# 2                                United States  September 8, 2018
# 3                                United States  September 8, 2018
# 4                                United States  September 8, 2017
# ...                                        ...                ...
# 6229                             United States                NaN
# 6230                             United States                NaN
# 6231                                       NaN                NaN
# 6232                            United Kingdom                NaN
# 6233                             United States                NaN
#
#       release_year    rating    duration  \
# 0             2019     TV-PG      90 min
# 1             2016     TV-MA      94 min
# 2             2013  TV-Y7-FV    1 Season
# 3             2016     TV-Y7    1 Season
# 4             2017     TV-14      99 min
# ...            ...       ...         ...
# 6229          2015        NR  13 Seasons
# 6230          2016     TV-MA   4 Seasons
# 6231          2016       NaN      60 min
# 6232          2013     TV-MA   2 Seasons
# 6233          2003     TV-14  10 Seasons
#
#                                               listed_in  \
# 0                    Children & Family Movies, Comedies
# 1                                       Stand-Up Comedy
# 2                                              Kids' TV
# 3                                              Kids' TV
# 4                                              Comedies
# ...                                                 ...
# 6229  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230                                        TV Comedies
# 6231                                             Movies
# 6232           British TV Shows, TV Comedies, TV Dramas
# 6233                     Classic & Cult TV, TV Comedies
#
#                                             description
# 0     Before planning an awesome wedding for his gra...
# 1     Jandino Asporaat riffs on the challenges of ra...
# 2     With the help of three human allies, the Autob...
# 3     When a prison ship crash unleashes hundreds of...
# 4     When nerdy high schooler Dani finally attracts...
# ...                                                 ...
# 6229  This parody of first-person shooter games, mil...
# 6230  Marc Maron stars as Marc Maron, who interviews...
# 6231  Nursery rhymes and original music for children...
# 6232  Set during the Russian Revolution, this comic ...
# 6233  This hit sitcom follows the merry misadventure...
#
# [6234 rows x 12 columns]

# %%
# Mostramos el número de filas

print('El número de filas es: ',len(df_netflix.index))
# Out:
# El número de filas es:  6234

# %%
# Mostramos los nombres de las columnas

print('Los nombres de las columnas son: ', list(df_netflix))
# Out:
# Los nombres de las columnas son:  ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']

# %% [markdown]
# ### Ejercicio 2
#
# Agrupa los datos cargados en el ejercicio 1 por **año** y, para cada año, muestra el número total de películas (*Movies*) y series de TV (*TV Show*) por separado.
#
# **Nota:** Al Notebook de teoría hemos visto cómo calcular la media de una agrupación de datos. Para resolver este ejercicio necesitarás investigar cómo contar (*count*) todos los valores de una columna en una agrupación. Te puede ser de utilidad la función [aggregate](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.aggregate.html) de pandas, la que nos permite aplicar diferentes funciones a una columna en un ```groupby```.

# %%
# Respuesta
# Observamos la parte que nos interesa del dataframe

df_netflix[['release_year', 'type']]
# Out:
#       release_year     type
# 0             2019    Movie
# 1             2016    Movie
# 2             2013  TV Show
# 3             2016  TV Show
# 4             2017    Movie
# ...            ...      ...
# 6229          2015  TV Show
# 6230          2016  TV Show
# 6231          2016    Movie
# 6232          2013  TV Show
# 6233          2003  TV Show
#
# [6234 rows x 2 columns]

# %%
# Agrupamos por año y por tipo (serie o película)

df_netflix_groupedby_year = df_netflix.groupby(['release_year', 'type'])


# Utilizamos la función 'aggregate' para contar los elementos por los que hemos agrupado

df_netflix_groupedby_year.aggregate('count')
# Out:
#                       show_id  title  director  cast  country  date_added  \
# release_year type
# 1925         TV Show        1      1         0     0        0           1
# 1942         Movie          2      2         2     1        2           2
# 1943         Movie          3      3         3     0        3           3
# 1944         Movie          3      3         3     1        3           3
# 1945         Movie          3      3         3     1        3           3
# ...                       ...    ...       ...   ...      ...         ...
# 2018         TV Show      417    417        28   360      360         416
# 2019         Movie        400    400       377   355      350         400
#              TV Show      443    443        26   390      377         443
# 2020         Movie          6      6         6     6        5           6
#              TV Show       19     19         2    17       13          19
#
#                       rating  duration  listed_in  description
# release_year type
# 1925         TV Show       1         1          1            1
# 1942         Movie         2         2          2            2
# 1943         Movie         3         3          3            3
# 1944         Movie         3         3          3            3
# 1945         Movie         3         3          3            3
# ...                      ...       ...        ...          ...
# 2018         TV Show     417       417        417          417
# 2019         Movie       400       400        400          400
#              TV Show     443       443        443          443
# 2020         Movie         6         6          6            6
#              TV Show      19        19         19           19
#
# [115 rows x 10 columns]

# %%
# Utilizo un for...loop para mostrar los resultados de series y películas reproducidas cada año

for name,group in df_netflix_groupedby_year:
    if name[1] == 'TV Show':
        print ('En',name[0],'se reprodujeron',len(group), 'series.')
    if name[1] == 'Movie':
        print ('En',name[0],'se reprodujeron',len(group), 'peliculas.')
# Out:
# En 1925 se reprodujeron 1 series.
# En 1942 se reprodujeron 2 peliculas.
# En 1943 se reprodujeron 3 peliculas.
# En 1944 se reprodujeron 3 peliculas.
# En 1945 se reprodujeron 3 peliculas.
# En 1946 se reprodujeron 2 peliculas.
# En 1946 se reprodujeron 1 series.
# En 1947 se reprodujeron 1 peliculas.
# En 1954 se reprodujeron 1 peliculas.
# En 1955 se reprodujeron 1 peliculas.
# En 1956 se reprodujeron 1 peliculas.
# En 1958 se reprodujeron 2 peliculas.
# En 1959 se reprodujeron 1 peliculas.
# En 1960 se reprodujeron 4 peliculas.
# En 1962 se reprodujeron 3 peliculas.
# En 1963 se reprodujeron 1 series.
# En 1964 se reprodujeron 1 peliculas.
# En 1965 se reprodujeron 2 peliculas.
# En 1966 se reprodujeron 1 peliculas.
# En 1967 se reprodujeron 2 peliculas.
# En 1967 se reprodujeron 1 series.
# En 1968 se reprodujeron 3 peliculas.
# En 1968 se reprodujeron 1 series.
# En 1969 se reprodujeron 2 peliculas.
# En 1970 se reprodujeron 1 peliculas.
# En 1971 se reprodujeron 3 peliculas.
# En 1972 se reprodujeron 3 peliculas.
# En 1972 se reprodujeron 1 series.
# En 1973 se reprodujeron 9 peliculas.
# En 1974 se reprodujeron 7 peliculas.
# En 1974 se reprodujeron 1 series.
# En 1975 se reprodujeron 5 peliculas.
# En 1976 se reprodujeron 7 peliculas.
# En 1977 se reprodujeron 4 peliculas.
# En 1977 se reprodujeron 1 series.
# En 1978 se reprodujeron 7 peliculas.
# En 1979 se reprodujeron 6 peliculas.
# En 1979 se reprodujeron 1 series.
# En 1980 se reprodujeron 7 peliculas.
# En 1981 se reprodujeron 6 peliculas.
# En 1981 se reprodujeron 1 series.
# En 1982 se reprodujeron 11 peliculas.
# En 1983 se reprodujeron 9 peliculas.
# En 1984 se reprodujeron 8 peliculas.
# En 1985 se reprodujeron 7 peliculas.
# En 1985 se reprodujeron 1 series.
# En 1986 se reprodujeron 8 peliculas.
# En 1986 se reprodujeron 2 series.
# En 1987 se reprodujeron 5 peliculas.
# En 1988 se reprodujeron 11 peliculas.
# En 1988 se reprodujeron 2 series.
# En 1989 se reprodujeron 10 peliculas.
# En 1989 se reprodujeron 1 series.
# En 1990 se reprodujeron 12 peliculas.
# En 1990 se reprodujeron 3 series.
# En 1991 se reprodujeron 14 peliculas.
# En 1991 se reprodujeron 1 series.
# En 1992 se reprodujeron 14 peliculas.
# En 1992 se reprodujeron 2 series.
# En 1993 se reprodujeron 16 peliculas.
# En 1993 se reprodujeron 3 series.
# En 1994 se reprodujeron 13 peliculas.
# En 1994 se reprodujeron 1 series.
# En 1995 se reprodujeron 15 peliculas.
# En 1995 se reprodujeron 2 series.
# En 1996 se reprodujeron 14 peliculas.
# En 1996 se reprodujeron 3 series.
# En 1997 se reprodujeron 27 peliculas.
# En 1997 se reprodujeron 4 series.
# En 1998 se reprodujeron 23 peliculas.
# En 1998 se reprodujeron 3 series.
# En 1999 se reprodujeron 17 peliculas.
# En 1999 se reprodujeron 4 series.
# En 2000 se reprodujeron 28 peliculas.
# En 2000 se reprodujeron 3 series.
# En 2001 se reprodujeron 30 peliculas.
# En 2001 se reprodujeron 4 series.
# En 2002 se reprodujeron 35 peliculas.
# En 2002 se reprodujeron 3 series.
# En 2003 se reprodujeron 35 peliculas.
# En 2003 se reprodujeron 8 series.
# En 2004 se reprodujeron 40 peliculas.
# En 2004 se reprodujeron 9 series.
# En 2005 se reprodujeron 51 peliculas.
# En 2005 se reprodujeron 12 series.
# En 2006 se reprodujeron 59 peliculas.
# En 2006 se reprodujeron 9 series.
# En 2007 se reprodujeron 60 peliculas.
# En 2007 se reprodujeron 11 series.
# En 2008 se reprodujeron 87 peliculas.
# En 2008 se reprodujeron 20 series.
# En 2009 se reprodujeron 87 peliculas.
# En 2009 se reprodujeron 34 series.
# En 2010 se reprodujeron 111 peliculas.
# En 2010 se reprodujeron 38 series.
# En 2011 se reprodujeron 100 peliculas.
# En 2011 se reprodujeron 36 series.
# En 2012 se reprodujeron 125 peliculas.
# En 2012 se reprodujeron 58 series.
# En 2013 se reprodujeron 177 peliculas.
# En 2013 se reprodujeron 60 series.
# En 2014 se reprodujeron 213 peliculas.
# En 2014 se reprodujeron 75 series.
# En 2015 se reprodujeron 363 peliculas.
# En 2015 se reprodujeron 154 series.
# En 2016 se reprodujeron 593 peliculas.
# En 2016 se reprodujeron 237 series.
# En 2017 se reprodujeron 682 peliculas.
# En 2017 se reprodujeron 277 series.
# En 2018 se reprodujeron 646 peliculas.
# En 2018 se reprodujeron 417 series.
# En 2019 se reprodujeron 400 peliculas.
# En 2019 se reprodujeron 443 series.
# En 2020 se reprodujeron 6 peliculas.
# En 2020 se reprodujeron 19 series.

# %% [markdown]
# ### Ejercicio 3
#
# Muestra las películas estrenadas el _2019_ que tienen una duración superior a _100_ minutos.
#
# **Nota:** Al Notebook de teoría hemos visto operaciones básicas de filtrado. Para resolver este ejercicio necesitarás investigar cómo aplicar condiciones más complejas.
#
# **Nota 2:** Los valores de la columna de duración (*duration*) son strings, ya que combinan números y letras. Por lo tanto, se tienen que transformar a int una vez se haya construido el subset de datos de películas. Te puede ser de utilidad la función [astype](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html) de pandas.

# %%
# Respuesta
# Dividimos la cadena del campo 'duration' por el primer espacio que aparezca, entre el número (duración de la película o temporadas de la serie) y la cadena ('min' or 'Season')

df_netflix.duration= df_netflix.duration.str.partition(' ')[0]

df_netflix
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# 6229                       NaN
# 6230                       NaN
# 6231                       NaN
# 6232                       NaN
# 6233                       NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3     Will Friedle, Darren Criss, Constance Zimmer, ...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...                                                 ...
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6231                                                NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                                        country         date_added  \
# 0     United States, India, South Korea, China  September 9, 2019
# 1                               United Kingdom  September 9, 2016
# 2                                United States  September 8, 2018
# 3                                United States  September 8, 2018
# 4                                United States  September 8, 2017
# ...                                        ...                ...
# 6229                             United States                NaN
# 6230                             United States                NaN
# 6231                                       NaN                NaN
# 6232                            United Kingdom                NaN
# 6233                             United States                NaN
#
#       release_year    rating duration  \
# 0             2019     TV-PG       90
# 1             2016     TV-MA       94
# 2             2013  TV-Y7-FV        1
# 3             2016     TV-Y7        1
# 4             2017     TV-14       99
# ...            ...       ...      ...
# 6229          2015        NR       13
# 6230          2016     TV-MA        4
# 6231          2016       NaN       60
# 6232          2013     TV-MA        2
# 6233          2003     TV-14       10
#
#                                               listed_in  \
# 0                    Children & Family Movies, Comedies
# 1                                       Stand-Up Comedy
# 2                                              Kids' TV
# 3                                              Kids' TV
# 4                                              Comedies
# ...                                                 ...
# 6229  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230                                        TV Comedies
# 6231                                             Movies
# 6232           British TV Shows, TV Comedies, TV Dramas
# 6233                     Classic & Cult TV, TV Comedies
#
#                                             description
# 0     Before planning an awesome wedding for his gra...
# 1     Jandino Asporaat riffs on the challenges of ra...
# 2     With the help of three human allies, the Autob...
# 3     When a prison ship crash unleashes hundreds of...
# 4     When nerdy high schooler Dani finally attracts...
# ...                                                 ...
# 6229  This parody of first-person shooter games, mil...
# 6230  Marc Maron stars as Marc Maron, who interviews...
# 6231  Nursery rhymes and original music for children...
# 6232  Set during the Russian Revolution, this comic ...
# 6233  This hit sitcom follows the merry misadventure...
#
# [6234 rows x 12 columns]

# %%
# Convertimos la columna 'duration' en 'integer' para poder comprarla con el número 100

df_netflix.duration = df_netflix.duration.astype(int)

# %%
# Creamos el subset solamente con los datos que nos interesan y observamos los datos

df_netflix_peliculas = df_netflix[['type', 'title', 'release_year', 'duration']]

df_netflix_peliculas
# Out:
#          type                                        title  release_year  \
# 0       Movie      Norm of the North: King Sized Adventure          2019
# 1       Movie                   Jandino: Whatever it Takes          2016
# 2     TV Show                           Transformers Prime          2013
# 3     TV Show             Transformers: Robots in Disguise          2016
# 4       Movie                                 #realityhigh          2017
# ...       ...                                          ...           ...
# 6229  TV Show                                 Red vs. Blue          2015
# 6230  TV Show                                        Maron          2016
# 6231    Movie       Little Baby Bum: Nursery Rhyme Friends          2016
# 6232  TV Show  A Young Doctor's Notebook and Other Stories          2013
# 6233  TV Show                                      Friends          2003
#
#       duration
# 0           90
# 1           94
# 2            1
# 3            1
# 4           99
# ...        ...
# 6229        13
# 6230         4
# 6231        60
# 6232         2
# 6233        10
#
# [6234 rows x 4 columns]

# %%
# Filtramos por tipo (película), año de estreno (2019) y duración (+100 min)

df_netflix_peliculas_2019 = df_netflix_peliculas[(df_netflix_peliculas.type == 'Movie') & (df_netflix_peliculas.release_year == 2019) & (df_netflix_peliculas.duration > 100)]

df_netflix_peliculas_2019
# Out:
#        type                            title  release_year  duration
# 35    Movie                       Article 15          2019       125
# 57    Movie                The World We Make          2019       108
# 102   Movie        In the Shadow of the Moon          2019       116
# 109   Movie                           Malaal          2019       133
# 119   Movie             Oh! Baby (Malayalam)          2019       146
# ...     ...                              ...           ...       ...
# 5347  Movie  Ek Ladki Ko Dekha Toh Aisa Laga          2019       120
# 5359  Movie                    Music Teacher          2019       102
# 5365  Movie                     The Ruthless          2019       111
# 5385  Movie    HOMECOMING: A film by Beyoncé          2019       138
# 5469  Movie                              706          2019       118
#
# [134 rows x 4 columns]

# %% [markdown]
# ### Ejercicio 4
#
# Queremos buscar aquellos países donde se estrenaron más de 10 películas al año. Debes mostrar por pantalla el **año**, el **nombre del país** y el **número total de películas** estrenadas en el año correspondiente.
#
# **Nota**: Además del contenido de los notebooks de teoría, puedes utilizar lo que has aprendido haciendo el ejercicio 2.

# %%
# Respuesta
# Visualizamos la parte del dataframe que nos interesa

df_netflix[['release_year', 'country', 'type']]
# Out:
#       release_year                                   country     type
# 0             2019  United States, India, South Korea, China    Movie
# 1             2016                            United Kingdom    Movie
# 2             2013                             United States  TV Show
# 3             2016                             United States  TV Show
# 4             2017                             United States    Movie
# ...            ...                                       ...      ...
# 6229          2015                             United States  TV Show
# 6230          2016                             United States  TV Show
# 6231          2016                                       NaN    Movie
# 6232          2013                            United Kingdom  TV Show
# 6233          2003                             United States  TV Show
#
# [6234 rows x 3 columns]

# %%
# Agrupamos por año, por país y por tipo

df_netflix_year_country = df_netflix.groupby(['release_year', 'country', 'type'])

df_netflix_year_country.aggregate('count')
# Out:
#                                                     show_id  title  director  \
# release_year country                       type
# 1942         United States                 Movie          2      2         2
# 1943         United States                 Movie          3      3         3
# 1944         United States                 Movie          2      2         2
#              United States, United Kingdom Movie          1      1         1
# 1945         United States                 Movie          3      3         3
# ...                                                     ...    ...       ...
# 2020         Mexico                        Movie          1      1         1
#              Spain                         Movie          1      1         1
#              United Kingdom                TV Show        1      1         0
#              United States                 Movie          2      2         2
#                                            TV Show        8      8         0
#
#                                                     cast  date_added  rating  \
# release_year country                       type
# 1942         United States                 Movie       1           2       2
# 1943         United States                 Movie       0           3       3
# 1944         United States                 Movie       0           2       2
#              United States, United Kingdom Movie       1           1       1
# 1945         United States                 Movie       1           3       3
# ...                                                  ...         ...     ...
# 2020         Mexico                        Movie       1           1       1
#              Spain                         Movie       1           1       1
#              United Kingdom                TV Show     1           1       1
#              United States                 Movie       2           2       2
#                                            TV Show     7           8       8
#
#                                                     duration  listed_in  \
# release_year country                       type
# 1942         United States                 Movie           2          2
# 1943         United States                 Movie           3          3
# 1944         United States                 Movie           2          2
#              United States, United Kingdom Movie           1          1
# 1945         United States                 Movie           3          3
# ...                                                      ...        ...
# 2020         Mexico                        Movie           1          1
#              Spain                         Movie           1          1
#              United Kingdom                TV Show         1          1
#              United States                 Movie           2          2
#                                            TV Show         8          8
#
#                                                     description
# release_year country                       type
# 1942         United States                 Movie              2
# 1943         United States                 Movie              3
# 1944         United States                 Movie              2
#              United States, United Kingdom Movie              1
# 1945         United States                 Movie              3
# ...                                                         ...
# 2020         Mexico                        Movie              1
#              Spain                         Movie              1
#              United Kingdom                TV Show            1
#              United States                 Movie              2
#                                            TV Show            8
#
# [1524 rows x 9 columns]

# %%
# Mostramos por pantalla el año, el nombre del país y el número total de películas estrenadas en el año correspondiente
# Iteramos mediante un for...loop por el subset agrupado
# Filtramos por películas y que se estrenasen más de 10 en el año

for name, group in df_netflix_year_country:
    if name[2] == 'Movie':
        if len(group) > 10:
            print(f'En el año {name[0]} se estrenaron en {name[1]} {len(group)} películas')
# Out:
# En el año 1997 se estrenaron en United States 17 películas
# En el año 1998 se estrenaron en United States 12 películas
# En el año 2000 se estrenaron en United States 14 películas
# En el año 2001 se estrenaron en United States 13 películas
# En el año 2002 se estrenaron en United States 12 películas
# En el año 2003 se estrenaron en United States 14 películas
# En el año 2004 se estrenaron en India 13 películas
# En el año 2004 se estrenaron en United States 11 películas
# En el año 2005 se estrenaron en India 17 películas
# En el año 2005 se estrenaron en United States 16 películas
# En el año 2006 se estrenaron en India 17 películas
# En el año 2006 se estrenaron en United States 24 películas
# En el año 2007 se estrenaron en India 13 películas
# En el año 2007 se estrenaron en United States 23 películas
# En el año 2008 se estrenaron en India 24 películas
# En el año 2008 se estrenaron en United States 28 películas
# En el año 2009 se estrenaron en India 24 películas
# En el año 2009 se estrenaron en United States 29 películas
# En el año 2010 se estrenaron en India 31 películas
# En el año 2010 se estrenaron en United States 25 películas
# En el año 2011 se estrenaron en India 26 películas
# En el año 2011 se estrenaron en United States 30 películas
# En el año 2012 se estrenaron en India 33 películas
# En el año 2012 se estrenaron en United States 40 películas
# En el año 2013 se estrenaron en India 44 películas
# En el año 2013 se estrenaron en United States 52 películas
# En el año 2014 se estrenaron en India 38 películas
# En el año 2014 se estrenaron en United Kingdom 13 películas
# En el año 2014 se estrenaron en United States 59 películas
# En el año 2015 se estrenaron en India 53 películas
# En el año 2015 se estrenaron en Spain 11 películas
# En el año 2015 se estrenaron en United Kingdom 18 películas
# En el año 2015 se estrenaron en United States 104 películas
# En el año 2016 se estrenaron en Canada 15 películas
# En el año 2016 se estrenaron en India 66 películas
# En el año 2016 se estrenaron en Mexico 13 películas
# En el año 2016 se estrenaron en Spain 14 películas
# En el año 2016 se estrenaron en United Kingdom 35 películas
# En el año 2016 se estrenaron en United States 185 películas
# En el año 2017 se estrenaron en Canada 20 películas
# En el año 2017 se estrenaron en India 99 películas
# En el año 2017 se estrenaron en Spain 18 películas
# En el año 2017 se estrenaron en United Kingdom 36 películas
# En el año 2017 se estrenaron en United States 260 películas
# En el año 2018 se estrenaron en Canada 18 películas
# En el año 2018 se estrenaron en India 79 películas
# En el año 2018 se estrenaron en South Korea 11 películas
# En el año 2018 se estrenaron en Spain 23 películas
# En el año 2018 se estrenaron en United Kingdom 26 películas
# En el año 2018 se estrenaron en United States 219 películas
# En el año 2019 se estrenaron en India 49 películas
# En el año 2019 se estrenaron en Spain 11 películas
# En el año 2019 se estrenaron en United Kingdom 11 películas
# En el año 2019 se estrenaron en United States 160 películas

# %% [markdown]
# ### Ejercicio 5
#
# Crea una copia del dataframe original añadiendo una nueva columna que nos indicará por cada fila la duración de la película. Definimos tres niveles:
#
# - **short** : si la duración es inferior a 90 minutos.
# - **medium** : si la duración está entre 90 y 150 minutos.
# - **long** : si la duración es superior a 150 minutos.
#
# Muestra por pantalla aquellas filas que correspondan a una duración corta ( _short_ ).
#
# **Nota:** pandas nos ofrece principalmente tres maneras de añadir nuevas columnas a un dataframe existente. Cualquiera de las tres formas son válidas para resolver este ejercicio. Podéis buscar en Internet cómo añadir columnas a un dataframe de pandas, ya que la documentación presenta los tres métodos de forma separada.

# %%
# Respuesta
# Creamos un nuevo dataframe solamente con las películas

new_df_netflix = df_netflix.drop(df_netflix[df_netflix.type == 'TV Show'].index)

new_df_netflix
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     80117401  Movie               Jandino: Whatever it Takes
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...        ...    ...                                      ...
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
# 6231  80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...                               ...
# 5577                 G.J. Echternkamp
# 5578                 G.J. Echternkamp
# 5579                   Zatella Beatty
# 5580                       Vlad Yudin
# 6231                              NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6     Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                       Fabrizio Copano
# ...                                                 ...
# 5577                                                NaN
# 5578  Rene Russo, Oliver Platt, Johnny Simmons, Jane...
# 5579                                      Allen Iverson
# 5580                                       Jeremy Scott
# 6231                                                NaN
#
#                                        country         date_added  \
# 0     United States, India, South Korea, China  September 9, 2019
# 1                               United Kingdom  September 9, 2016
# 4                                United States  September 8, 2017
# 6       Bulgaria, United States, Spain, Canada  September 8, 2017
# 7                                        Chile  September 8, 2017
# ...                                        ...                ...
# 5577                             United States      April 1, 2016
# 5578                             United States      April 1, 2016
# 5579                             United States      April 1, 2016
# 5580                             United States      April 1, 2016
# 6231                                       NaN                NaN
#
#       release_year rating  duration  \
# 0             2019  TV-PG        90
# 1             2016  TV-MA        94
# 4             2017  TV-14        99
# 6             2014      R       110
# 7             2017  TV-MA        60
# ...            ...    ...       ...
# 5577          2007  TV-MA        70
# 5578          2015      R       102
# 5579          2014     NR        88
# 5580          2015  PG-13       109
# 6231          2016    NaN        60
#
#                                               listed_in  \
# 0                    Children & Family Movies, Comedies
# 1                                       Stand-Up Comedy
# 4                                              Comedies
# 6     International Movies, Sci-Fi & Fantasy, Thrillers
# 7                                       Stand-Up Comedy
# ...                                                 ...
# 5577                                      Documentaries
# 5578               Comedies, Dramas, Independent Movies
# 5579                       Documentaries, Sports Movies
# 5580                                      Documentaries
# 6231                                             Movies
#
#                                             description
# 0     Before planning an awesome wedding for his gra...
# 1     Jandino Asporaat riffs on the challenges of ra...
# 4     When nerdy high schooler Dani finally attracts...
# 6     In a dystopian future, an insurance adjuster f...
# 7     Fabrizio Copano takes audience participation t...
# ...                                                 ...
# 5577  Frank was a rising pop star when he married Ci...
# 5578  A student filmmaker vengefully turns his camer...
# 5579  This unfiltered documentary follows the rocky ...
# 5580  The journey of fashion designer Jeremy Scott f...
# 6231  Nursery rhymes and original music for children...
#
# [4265 rows x 12 columns]

# %%
# Creamos una función que asigne rangos en función de la duración de las películas

def ranges(movie):
    movie = movie.duration
    if movie < 90:
        return 'short'
    elif movie > 150:
        return 'long'
    else:
        return 'medium'

# %%
# Añadimos una nueva columna al dataframe para los difrentes rangos de duración de las películas, aplicando a la columna la función creada

new_df_netflix['duration_range'] = new_df_netflix.apply(ranges, axis = 1)

new_df_netflix
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     80117401  Movie               Jandino: Whatever it Takes
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...        ...    ...                                      ...
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
# 6231  80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# 7     Rodrigo Toro, Francisco Schultz
# ...                               ...
# 5577                 G.J. Echternkamp
# 5578                 G.J. Echternkamp
# 5579                   Zatella Beatty
# 5580                       Vlad Yudin
# 6231                              NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6     Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                       Fabrizio Copano
# ...                                                 ...
# 5577                                                NaN
# 5578  Rene Russo, Oliver Platt, Johnny Simmons, Jane...
# 5579                                      Allen Iverson
# 5580                                       Jeremy Scott
# 6231                                                NaN
#
#                                        country         date_added  \
# 0     United States, India, South Korea, China  September 9, 2019
# 1                               United Kingdom  September 9, 2016
# 4                                United States  September 8, 2017
# 6       Bulgaria, United States, Spain, Canada  September 8, 2017
# 7                                        Chile  September 8, 2017
# ...                                        ...                ...
# 5577                             United States      April 1, 2016
# 5578                             United States      April 1, 2016
# 5579                             United States      April 1, 2016
# 5580                             United States      April 1, 2016
# 6231                                       NaN                NaN
#
#       release_year rating  duration  \
# 0             2019  TV-PG        90
# 1             2016  TV-MA        94
# 4             2017  TV-14        99
# 6             2014      R       110
# 7             2017  TV-MA        60
# ...            ...    ...       ...
# 5577          2007  TV-MA        70
# 5578          2015      R       102
# 5579          2014     NR        88
# 5580          2015  PG-13       109
# 6231          2016    NaN        60
#
#                                               listed_in  \
# 0                    Children & Family Movies, Comedies
# 1                                       Stand-Up Comedy
# 4                                              Comedies
# 6     International Movies, Sci-Fi & Fantasy, Thrillers
# 7                                       Stand-Up Comedy
# ...                                                 ...
# 5577                                      Documentaries
# 5578               Comedies, Dramas, Independent Movies
# 5579                       Documentaries, Sports Movies
# 5580                                      Documentaries
# 6231                                             Movies
#
#                                             description duration_range
# 0     Before planning an awesome wedding for his gra...         medium
# 1     Jandino Asporaat riffs on the challenges of ra...         medium
# 4     When nerdy high schooler Dani finally attracts...         medium
# 6     In a dystopian future, an insurance adjuster f...         medium
# 7     Fabrizio Copano takes audience participation t...          short
# ...                                                 ...            ...
# 5577  Frank was a rising pop star when he married Ci...          short
# 5578  A student filmmaker vengefully turns his camer...         medium
# 5579  This unfiltered documentary follows the rocky ...          short
# 5580  The journey of fashion designer Jeremy Scott f...         medium
# 6231  Nursery rhymes and original music for children...          short
#
# [4265 rows x 13 columns]

# %%
# Mostramos solamente aquellas que corresponden al rango de duración 'short'

new_df_netflix_short = new_df_netflix[new_df_netflix.duration_range == 'short']
new_df_netflix_short
# Out:
#        show_id   type                                              title  \
# 7     80164077  Movie                 Fabrizio Copano: Solo pienso en mi
# 10    80169755  Movie                        Joaquín Reyes: Una y no más
# 12    80182480  Movie                           Krish Trish and Baltiboy
# 13    80182483  Movie           Krish Trish and Baltiboy: Battle of Wits
# 14    80182596  Movie     Krish Trish and Baltiboy: Best Friends Forever
# ...        ...    ...                                                ...
# 5573  80171439  Movie  The Human Factor: The Untold Story of the Bomb...
# 5574  80104237  Movie                                      The Tenth Man
# 5577  80085438  Movie                                    Frank and Cindy
# 5579  80011846  Movie                                            Iverson
# 6231  80116008  Movie             Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 7     Rodrigo Toro, Francisco Schultz
# 10              José Miguel Contreras
# 12                                NaN
# 13        Munjal Shroff, Tilak Shetty
# 14        Munjal Shroff, Tilak Shetty
# ...                               ...
# 5573          Rudradeep Bhattacharjee
# 5574                    Daniel Burman
# 5577                 G.J. Echternkamp
# 5579                   Zatella Beatty
# 6231                              NaN
#
#                                                    cast        country  \
# 7                                       Fabrizio Copano          Chile
# 10                                        Joaquín Reyes            NaN
# 12    Damandeep Singh Baggan, Smita Malhotra, Baba S...            NaN
# 13    Damandeep Singh Baggan, Smita Malhotra, Baba S...            NaN
# 14    Damandeep Singh Baggan, Smita Malhotra, Deepak...            NaN
# ...                                                 ...            ...
# 5573                                                NaN          India
# 5574  Alan Sabbagh, Julieta Zylberberg, Usher Barilk...      Argentina
# 5577                                                NaN  United States
# 5579                                      Allen Iverson  United States
# 6231                                                NaN            NaN
#
#              date_added  release_year rating  duration  \
# 7     September 8, 2017          2017  TV-MA        60
# 10    September 8, 2017          2017  TV-MA        78
# 12    September 8, 2017          2009  TV-Y7        58
# 13    September 8, 2017          2013  TV-Y7        62
# 14    September 8, 2017          2016   TV-Y        65
# ...                 ...           ...    ...       ...
# 5573      April 1, 2017          2013  TV-PG        53
# 5574      April 1, 2017          2016  TV-MA        81
# 5577      April 1, 2016          2007  TV-MA        70
# 5579      April 1, 2016          2014     NR        88
# 6231                NaN          2016    NaN        60
#
#                                               listed_in  \
# 7                                       Stand-Up Comedy
# 10                                      Stand-Up Comedy
# 12                             Children & Family Movies
# 13                             Children & Family Movies
# 14                             Children & Family Movies
# ...                                                 ...
# 5573  Documentaries, International Movies, Music & M...
# 5574                       Dramas, International Movies
# 5577                                      Documentaries
# 5579                       Documentaries, Sports Movies
# 6231                                             Movies
#
#                                             description duration_range
# 7     Fabrizio Copano takes audience participation t...          short
# 10    Comedian and celebrity impersonator Joaquín Re...          short
# 12    A team of minstrels, including a monkey, cat a...          short
# 13    An artisan is cheated of his payment, a lion o...          short
# 14    A cat, monkey and donkey team up to narrate fo...          short
# ...                                                 ...            ...
# 5573  A family of Parsi musicians collectively works...          short
# 5574  After spending much of his adult life in New Y...          short
# 5577  Frank was a rising pop star when he married Ci...          short
# 5579  This unfiltered documentary follows the rocky ...          short
# 6231  Nursery rhymes and original music for children...          short
#
# [1362 rows x 13 columns]

# %% [markdown]
# ### Ejercicio 6
#
# En este ejercicio trabajaremos con el dataset de Netflix, pero analizando las series de TV. Muestra un gráfico de barras con el número de series de TV americanas agrupadas por categoría (*listed_in*).
#
#
# Consideraciones:
#
# - Debes mostrar los datos de manera horizontal (barras horizontales).
# - El eje de las Y debe incluir las etiquetas de las categorías de las series de TV.
# - Debe incluir un texto con el número de series por cada categoría del gráfico. El texto debería estar situado a la derecha de cada barra.
#
# **Nota**: En el Notebook de teoría hemos visto cómo mostrar gráficos lineares simples con el matplotlib. Para este ejercicio explora las funcionalidades que presenta la librería pandas para generar gráficos a partir de dataframes. También pueden ser de utilidad las funciones [text](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.text.html) o [annotate](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.annotate.html) para mostrar el número de series al lado de cada barra.

# %%
# Respuesta

# %% [markdown]
# ### Ejercicio Opcional
#
# Python es un lenguaje de programación muy utilizado en el procesamiento de imágenes. En este ejercicio veremos una aplicación de detección de elementos en una imagen de microscopía de escaneo (en inglés: Scanning Element Microscopy (SEM)).
#
# En esta imagen se puede ver una muestra de vidrio (gris claro) con algunas burbujas (elementos negros) y granos de arena (gris oscuro). Queremos ser capaces de detectar los diferentes elementos de la muestra a partir de la imagen.
#
# Una imagen se puede ver como una matriz bidimensional donde cada elemento de la matriz corresponde al valor de un pixel de la imagen. Por ejemplo, si miramos la matriz de la imagen que os proporcionamos, veremos valores que van de 0 a 255. Así pues, para distinguir los diferentes elementos de la muestra de vidrio, nos tendremos que fijar en el nivel de gris de los píxeles de la imagen a través del histograma. <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px; ">EI</span>
#
#
# Parte A:
#
# * Para poder identificar mejor los elementos de la muestra de vidrio, primero hemos aplicado un filtro de mediana para reducir el ruido. Grafica ahora la distribución de los píxeles de la imagen inicial y la imagen filtrada. ¿Qué diferencia puedes apreciar entre ambas distribuciones?
#
# **Nota:** Utiliza la función [distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html) de la librería Seaborn para visualizar la distribución de los valores píxeles de la imagen.
#
# Parte B:
#
# * Utilizando los valores del distribution plot de la imagen filtrada, determina unos umbrales que permitan diferenciar los píxeles de arena, los píxeles de vidrio y los píxeles de burbuja.
#
# * Una vez que hayas definido los umbrales, muestra por pantalla una imagen donde cada uno de los elementos esté en un color diferente.

# %%
# Respuesta
